# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('Test figure')        
plt.show()

# %%
# Object-oriented
# Full control of your figure

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(3,3))
ax.bar(x=['A','B','C'], height=[3.1,7,4.2], color='k')
ax.set_xlabel(xlabel='X title', size=15)
ax.set_ylabel(ylabel='Y title' , color='k', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %%
# heat map
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(dict(categorical_1=['C1', 'C2', 'C3',
                                      'C1', 'C2', 'C3',
                                      'C1', 'C2', 'C3'], 
                  categorical_2=['A','A','A','B','B','B','C','C','C'], 
                  value=[10,2,5,7,3,15,1,6,8]))
pivot_table = df.pivot("categorical_1", "categorical_2", "value")

# try printing out pivot_table to see what it looks like!
f, ax= plt.subplots(figsize=(6,6))

ax=sns.heatmap(data=pivot_table, 
            cmap=sns.color_palette("coolwarm"),
            ax=ax,
            annot=True,annot_kws={'size':15})

cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=15)

ax.set_xlabel(xlabel='X title', size=15)
ax.set_ylabel(ylabel='Y title' , color='k', size=15)

ax.tick_params(axis='both', which='major', labelsize=15)


plt.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     700             self.info(buf=buf)
#     701             # need to escape the <class>, should be the first line.
# --> 702             val = buf.getvalue().replace("<", r"&lt;", 1)
#     703             val = val.replace(">", r"&gt;", 1)
#     704             return "<pre>" + val + "</pre>"
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
# ...

# %%
# overlay plot
fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=['A','B','C','D'], 
             y=[4,2,5,3],
             color='r',
             ax=ax)
sns.lineplot(x=['A','B','C','D'], 
             y=[1,6,2,4], 
             color='b',
             ax=ax)    
ax.legend(['alpha', 'beta'], facecolor='w', fontsize=15)

ax.tick_params(axis='both', which='major', labelsize=15)

plt.show()

# %%
# when two plots are in different scale 
sns.set(style="white", rc={"lines.linewidth": 3})

fig, ax1 = plt.subplots(figsize=(4,4))
ax2 = ax1.twinx()

sns.barplot(x=['A','B','C','D'],
            y=[100,200,135,98], 
            color='#004488',
            ax=ax1)

sns.lineplot(x=['A','B','C','D'], 
             y=[4,2,5,3],
             color='r',
             marker="o",
             ax=ax2)

ax1.tick_params(axis='both', which='major', labelsize=15)
ax2.tick_params(axis='both', which='major', labelsize=15)

ax1.set_xlabel(xlabel='X title', size=15)
ax1.set_ylabel(ylabel='Y title 1' , color='k', size=15)

ax2.set_ylabel(ylabel='Y title 2' , color='k', size=15)
ax2.yaxis.set_label_position("right")

plt.show()
sns.set()

# %%
import matplotlib.pyplot as plt

categorical_1 = ['A', 'B', 'C', 'D']
colors        = ['green', 'red', 'blue', 'orange']
numerical = [[6, 9, 2, 7],
             [6, 7, 3, 8],
             [9, 11, 13, 15],
             [3, 5, 9, 6]]

number_groups = len(categorical_1) 
bin_width = 1.0/(number_groups+1)

fig, ax = plt.subplots(figsize=(6,6))

for i in range(number_groups):
    ax.bar(x=np.arange(len(categorical_1)) + i*bin_width, 
           height=numerical[i],
           width=bin_width,
           color=colors[i],
           align='center')
    
ax.set_xticks(np.arange(len(categorical_1)) + number_groups/(2*(number_groups+1)))# number_groups/(2*(number_groups+1)): offset of xticklabelax.set_xticklabels(categorical_1)
ax.legend(categorical_1, facecolor='w', fontsize=15)

ax.tick_params(axis='both', which='major', labelsize=15)

plt.show()

# %%
import seaborn as sns

tips = sns.load_dataset("tips")
fig, ax = plt.subplots(figsize=(8,8))
ax = sns.scatterplot(x="total_bill", y="tip",                      
                     hue="size", size="size",
                     sizes=(20, 200), palette="Set2",
                     legend="full", data=tips)

ax.legend(facecolor='w', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel(xlabel='Total_Bill', size=15)
ax.set_ylabel(ylabel='Tip' , color='k', size=15)

plt.show()

# %%
tips
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     700             self.info(buf=buf)
#     701             # need to escape the <class>, should be the first line.
# --> 702             val = buf.getvalue().replace("<", r"&lt;", 1)
#     703             val = val.replace(">", r"&gt;", 1)
#     704             return "<pre>" + val + "</pre>"
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
# ...

# %%
# partition the figure into several subplots
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(7,7))
gs = gridspec.GridSpec(nrows=3, 
                       ncols=3, 
                       figure=fig, 
                       width_ratios= [1, 1, 1],
                       height_ratios=[1, 1, 1],
                       wspace=0.3,
                       hspace=0.3)

ax1 = fig.add_subplot(gs[0, 0])
ax1.text(0.5, 0.5, 'ax1: gs[0, 0]', fontsize=15, fontweight="bold", va="center", ha="center")  # adding text to ax1

ax2 = fig.add_subplot(gs[0, 1:3])
ax2.text(0.5, 0.5, 'ax2: gs[0, 1:3]', fontsize=15, fontweight="bold", va="center", ha="center")

ax3 = fig.add_subplot(gs[1:3, 0:2])
ax3.text(0.5, 0.5, 'ax3: gs[1:3, 0:2]', fontsize=15, fontweight="bold", va="center", ha="center")

ax4 = fig.add_subplot(gs[1:3, 2])
ax4.text(0.5, 0.5, 'ax4: gs[1:3, 2]', fontsize=15, fontweight="bold", va="center", ha="center")

plt.show()

# %%
import geoplotlib
from geoplotlib.utils import read_csv


data = read_csv('./data/flights.csv')
geoplotlib.graph(data,
                 src_lat='lat_departure',
                 src_lon='lon_departure',
                 dest_lat='lat_arrival',
                 dest_lon='lon_arrival',
                 color='hot_r',
                 alpha=16,
                 linewidth=2)
geoplotlib.show()

# %%
"""
Example of animation and dynamic camera adjustment
"""
from geoplotlib.layers import BaseLayer
from geoplotlib.core import BatchPainter
import geoplotlib
from geoplotlib.utils import epoch_to_str, BoundingBox, read_csv


class TrailsLayer(BaseLayer):

    def __init__(self):
        self.data = read_csv('data/taxi.csv')
        self.data = self.data.where(self.data['taxi_id'] == list(set(self.data['taxi_id']))[2])
        self.t = self.data['timestamp'].min()
        self.painter = BatchPainter()


    def draw(self, proj, mouse_x, mouse_y, ui_manager):
        self.painter = BatchPainter()
        self.painter.set_color([0,0,255])
        df = self.data.where((self.data['timestamp'] > self.t) & (self.data['timestamp'] <= self.t + 30*60))
        proj.fit(BoundingBox.from_points(lons=df['lon'], lats=df['lat']), max_zoom=12)
        x, y = proj.lonlat_to_screen(df['lon'], df['lat'])
        self.painter.linestrip(x, y, 10)
        self.t += 30
        if self.t > self.data['timestamp'].max():
            self.t = self.data['timestamp'].min()

        self.painter.batch_draw()
        ui_manager.info(epoch_to_str(self.t))


geoplotlib.add_layer(TrailsLayer())
geoplotlib.show()

# %%
data = read_csv('data/taxi.csv')

# %%
plt.plot(data['taxi_id'])
#plt.plot(data['lon'])
#plt.plot(data['lat'])

# %%
# libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
# Build a dataframe with 4 connections
df = pd.DataFrame({ 'from':['A', 'B', 'C','A'], 'to':['D', 'A', 'E','C']})
df
 
# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to')

pos = nx.layout.spring_layout(G)

# nodes
nx.draw(G, pos,with_labels=False,node_size=10000,node_color="red",alpha=1,linewidths=40)

nx.draw_networkx_labels(G,pos,font_size=20)

plt.show()

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.sankey import Sankey
 
# basic sankey chart
Sankey(flows=[0.25, 0.15, 0.60, -0.20, -0.15, -0.05, -0.50, -0.10], 
       labels=['', '', '', 'First', 'Second', 'Third', 'Fourth', 'Fifth'], 
       orientations=[-1, 1, 0, 1, 1, 1, 0,-1]).finish()
plt.title("Sankey diagram with default settings",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Sankey diagram with default settings')
